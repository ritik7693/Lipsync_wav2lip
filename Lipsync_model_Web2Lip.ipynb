# %% [markdown]
# <a href="https://colab.research.google.com/github/ritik7693/Lipsync_wav2lip/blob/main/Lipsync_model_Web2Lip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install librosa==0.8.0
# Out:
# ...
# '!pip install gfpgan\n!pip install realesrgan'

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.

# %%
# !ls /content/gdrive/MyDrive/wav2lib_files
# Out:
# output10.wav  video720Q.mp4  video.mp4	wav2lip.pth

# %%
# !cp -ri "/content/gdrive/MyDrive/wav2lib_files/wav2lip.pth" /content/Wav2Lip/checkpoints/
# Out:
# cp: overwrite '/content/Wav2Lip/checkpoints/wav2lip.pth'? y

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt
# Out:
# ...
#   Using cached librosa-0.7.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached numpy-1.17.1.zip (6.5 MB)
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.1.0.25 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72, 4.8.0.74)
# ERROR: No matching distribution found for opencv-python==4.1.0.25

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2023-07-13 19:26:24--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M  13.0MB/s    in 7.7s
#
# 2023-07-13 19:26:33 (11.1 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %%
# !cp "/content/gdrive/MyDrive/wav2lib_files/video720Q.mp4" "/content/gdrive/MyDrive/wav2lib_files/output10.wav" sample_data/
# !ls sample_data/
# Out:
# anscombe.json		      mnist_test.csv	     README.md
# california_housing_test.csv   mnist_train_small.csv  video720Q.mp4
# california_housing_train.csv  output10.wav	     video.mp4

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path '../Wav2Lip/checkpoints/wav2lip.pth' --face "../sample_data/video.mp4" --audio "../sample_data/output10.wav" --nosmooth --pads 0 10 0 0
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 15120
# (80, 5386)
# Length of mel chunks: 1680
#   0% 0/14 [00:00<?, ?it/s]Reading video frames from start...
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:06<00:00,  6.99s/it]
#
# 100% 1/1 [00:00<00:00, 23.85it/s]
#
# 100% 1/1 [00:00<00:00, 24.02it/s]
#
# 100% 1/1 [00:00<00:00, 25.42it/s]
#
# 100% 1/1 [00:00<00:00, 25.23it/s]
#
# 100% 1/1 [00:00<00:00, 25.79it/s]
#
# 100% 1/1 [00:00<00:00, 22.78it/s]
#
# 100% 1/1 [00:00<00:00, 18.41it/s]
#
# 100% 1/1 [00:00<00:00, 17.90it/s]
#
# 100% 1/1 [00:00<00:00, 17.18it/s]
#
# 100% 1/1 [00:00<00:00, 16.91it/s]
#
# 100% 1/1 [00:00<00:00, 16.04it/s]
#
# 100% 1/1 [00:00<00:00, 15.43it/s]
#
# 100% 1/1 [00:00<00:00, 15.36it/s]
#
# 100% 1/1 [00:00<00:00, 15.31it/s]
#
# 100% 1/1 [00:00<00:00, 15.28it/s]
#
# 100% 1/1 [00:00<00:00, 15.38it/s]
#
# 100% 1/1 [00:00<00:00, 15.42it/s]
#
# 100% 1/1 [00:00<00:00, 14.60it/s]
#
# 100% 1/1 [00:00<00:00, 15.26it/s]
#
# ...
